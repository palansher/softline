# %%
import pandas as pd
from sqlalchemy import create_engine

# Создаем подключение (например, к SQLite или удаленному серверу)
engine = create_engine('postgresql://postgres:admin@localhost/m3_4_lab') 

# Загружаем данные из БД сразу в DataFrame
df = pd.read_sql("SELECT * FROM person", engine)
df.head()
# Out:
#    id_person             fio   salary   department   hire_date
# 0          1     Иванов И.И.  50000.0           IT  2020-01-15
# 1          2     Петров П.П.  45000.0  Бухгалтерия  2019-03-20
# 2          3    Сидоров С.С.  55000.0           IT  2021-06-10
# 3          4  Кузнецова Е.В.  48000.0           HR  2018-11-05
# 4          5    Смирнов А.А.  52000.0    Маркетинг  2022-02-28
